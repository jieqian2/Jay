# %% [markdown]
# # PART I
# Introduction/Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:\\Users\\Zilean\\Desktop\\IE598_Midterm_1\\MLF_GP1_CreditScore.csv",header=0)
df.head()
# Out:
#    Sales/Revenues  Gross Margin    EBITDA  EBITDA Margin  \
# 0       -0.005496      0.030763  0.018885       0.024515
# 1       -0.005496      0.030763  0.088716       0.094733
# 2       -0.007045      0.023159  0.088716       0.096440
# 3       -0.009396      0.028400  0.088716       0.099046
# 4       -0.009009      0.027714  0.088716       0.098611
#
#    Net Income Before Extras  Total Debt  Net Debt   LT Debt   ST Debt  \
# 0                  0.146849   -0.029710 -0.019296 -0.042648  0.049875
# 1                  0.146849   -0.029710 -0.019296 -0.042648  0.049875
# 2                  0.108590    0.039410  0.034268  0.009059  0.250371
# 3                  0.146137    0.030071  0.036938 -0.016964  0.356994
# 4                  0.123500    0.024224  0.034445 -0.034132  0.461894
#
#        Cash  ...  Interest Coverage  Total Liquidity  Current Liquidity  \
# 0 -0.133716  ...           0.136748         0.392143          -0.184887
# ...

# %%
df.describe()
# Out:
#        Sales/Revenues  Gross Margin       EBITDA  EBITDA Margin  \
# count     1700.000000   1700.000000  1700.000000    1700.000000
# mean         0.050378      0.026007     0.068718       0.021074
# std          0.161910      0.273768     0.237365       0.189025
# min         -0.661715     -0.794722    -0.782254      -0.805153
# 25%         -0.005693     -0.020028    -0.022640      -0.042771
# 50%          0.034000      0.003403     0.049482       0.011134
# 75%          0.083004      0.025595     0.124533       0.060566
# max          2.277229      3.202713     3.542425       4.141182
#
#        Net Income Before Extras   Total Debt     Net Debt      LT Debt  \
# count               1700.000000  1700.000000  1700.000000  1700.000000
# mean                   0.123026     0.822405    -0.419810     1.255168
# std                   14.475689    13.317075    28.385702    16.224453
# min                 -289.000000    -0.903014  -493.305578    -0.921515
# ...

# %%
df.dropna()
df.isnull().values.any()
# Out:
# False

# %%
print(df.dtypes)
# Out:
# Sales/Revenues              float64
# Gross Margin                float64
# EBITDA                      float64
# EBITDA Margin               float64
# Net Income Before Extras    float64
# Total Debt                  float64
# Net Debt                    float64
# LT Debt                     float64
# ST Debt                     float64
# Cash                        float64
# Free Cash Flow              float64
# Total Debt/EBITDA           float64
# Net Debt/EBITDA             float64
# Total MV                    float64
# Total Debt/MV               float64
# Net Debt/MV                 float64
# CFO/Debt                    float64
# CFO                         float64
# Interest Coverage           float64
# Total Liquidity             float64
# Current Liquidity           float64
# Current Liabilities         float64
# EPS Before Extras           float64
# PE                          float64
# ROA                         float64
# ROE                         float64
# ...

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(111)
stats.probplot(df['ROE'], dist="norm",plot=ax)
plt.title("ROE Q-Q Plot")
plt.show()

# %%
import sys
Rating=df['Rating']
Categories=set(Rating)
sys.stdout.write("Unique Label Values \n")
print(Categories)
sys.stdout.write(" \n")
# Out:
# Unique Label Values
# {'A1', 'Aa3', 'B2', 'Ba3', 'Baa3', 'A3', 'Baa1', 'Ba1', 'Baa2', 'A2', 'B1', 'Aa2', 'B3', 'Caa1', 'Ba2', 'Aaa'}

# %%
sys.stdout.write("\nCounts for Each Value of Categorical Label \n")
catCount={}
for elt in Rating:
    if elt in catCount:
        catCount[elt] += 1
    else:
        catCount[elt]=1
print(catCount)
# Out:
# Counts for Each Value of Categorical Label
# {'A1': 122, 'A2': 156, 'A3': 31, 'Aa2': 65, 'Aa3': 174, 'Aaa': 2, 'B1': 69, 'B2': 48, 'B3': 37, 'Ba1': 17, 'Ba2': 125, 'Ba3': 108, 'Baa1': 179, 'Baa2': 326, 'Baa3': 232, 'Caa1': 9}

# %%
X=df.iloc[:,:-3]
y=df.iloc[:,-2]
y_mul=df.iloc[:,-1]

# %%
from pandas import DataFrame
corMat=DataFrame(X.corr())
plt.pcolor(corMat)
plt.show()

# %%
import seaborn as sns
cols = ['Sales/Revenues','EBITDA','Total Debt','Total Liquidity','ROE']
sns.pairplot(df[cols], height=2.5)
plt.tight_layout()
plt.show()

# %%
cm=np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.5)
hm=sns.heatmap(cm,
               cbar=True, 
               annot=True, 
               square=True, fmt='.1f',
               annot_kws={'size':15},
               yticklabels=cols,xticklabels=cols)
plt.show()

# %% [markdown]
# # PART II
# Preprocessing, feature extraction, feature selection

# %%
X=df.iloc[:,:-3]
y=df.iloc[:,-2]
y_mul=df.iloc[:,-1]
normalized_X = X.apply(lambda x : (x-np.min(x))/(np.max(x)-np.min(x)))
normalized_X.describe()
# Out:
#        Sales/Revenues  Gross Margin       EBITDA  EBITDA Margin  \
# count     1700.000000   1700.000000  1700.000000    1700.000000
# mean         0.242295      0.205314     0.196771       0.167038
# std          0.055091      0.068486     0.054886       0.038215
# min          0.000000      0.000000     0.000000       0.000000
# 25%          0.223217      0.193798     0.175646       0.154131
# 50%          0.236723      0.199659     0.192323       0.165029
# 75%          0.253397      0.205211     0.209677       0.175022
# max          1.000000      1.000000     1.000000       1.000000
#
#        Net Income Before Extras   Total Debt     Net Debt      LT Debt  \
# count               1700.000000  1700.000000  1700.000000  1700.000000
# mean                   0.376816     0.006108     0.362816     0.007498
# std                    0.018866     0.047139     0.020895     0.055887
# min                    0.000000     0.000000     0.000000     0.000000
# ...

# %% [markdown]
# #
# Feature Extraction - PCA

# %%
# Reference Datacamp
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Create scaler: scaler
scaler = StandardScaler()

# Create a PCA instance: pca
pca = PCA()

# Create pipeline: pipeline
pipeline = make_pipeline(scaler,pca)

# Fit the pipeline to 'X'
pipeline.fit(X)

# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.title("PCA Feature")
plt.show()

# %%
pca=PCA(n_components=7)
pca.fit(normalized_X)
pca_X=pca.transform(normalized_X)
print(pca_X.shape)
# Out:
# (1700, 7)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(pca_X,y,test_size=0.2,random_state=42)

# %% [markdown]
# #  PART III Binary Class
# Model fitting and evaluation-- Overview

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# Set seed for reproducibility
SEED=42
# Instantiate lr
lr = LogisticRegression(random_state=SEED)
# Instantiate knn
knn = KNN(n_neighbors=10)
# Instantiate dt
dt = DecisionTreeClassifier(min_samples_leaf=0.13, random_state=SEED)
# Instantiate SVC
svc=SVC(kernel="rbf")
# Define the list classifiers
classifiers = [('Logistic Regression', lr), ('K Nearest Neighbours', knn), ('Classification Tree', dt),('SVC',svc)]

# Iterate over the pre-defined list of classifiers
for clf_name, clf in classifiers:     
    # Fit clf to the training set
    clf.fit(X_train, y_train)       
    # Predict y_pred
    y_pred = clf.predict(X_test)   
    # Calculate accuracy
    accuracy = accuracy_score(y_pred, y_test) 
    # Evaluate clf's accuracy on the test set
    print('{:s} : {:.3f}'.format(clf_name, accuracy)) 
    # Evalutate MSE
    print('MSE test: %.3f' % (mean_squared_error(y_test, y_pred)))
    # Evalutate R^2
    # print('R^2 test: %.3f' % (r2_score(y_test, y_pred)))
    print("-------------------------------------------")
# Out:
# Logistic Regression : 0.756
# MSE test: 0.244
# -------------------------------------------
# K Nearest Neighbours : 0.785
# MSE test: 0.215
# -------------------------------------------
# Classification Tree : 0.753
# MSE test: 0.247
# -------------------------------------------
# SVC : 0.756
# MSE test: 0.244
# -------------------------------------------
# G:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# G:\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [markdown]
# #
# Model fitting and evaluation--Logreg

# %%
# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
import math

# Create the hyperparameter grid
c_space = np.linspace(1,20,num = 20)
param_grid = {'C': c_space}

# Instantiate the logistic regression classifier: logreg
logreg = LogisticRegression(solver='lbfgs')

# Instantiate the GridSearchCV object: logreg_cv
logreg_cv = GridSearchCV(logreg,param_grid,cv=10)

# Fit it to the training data
logreg_cv.fit(X_train,y_train)

# Print the optimal parameters and best score
print("Tuned Logistic Regression Parameter: {}".format(logreg_cv.best_params_))
print("Tuned Logistic Regression Accuracy: {}".format(logreg_cv.best_score_))
# Out:
# Tuned Logistic Regression Parameter: {'C': 3.0}
# Tuned Logistic Regression Accuracy: 0.7617647058823529

# %%
best_logreg=LogisticRegression(C=13,solver='lbfgs')
best_logreg.fit(X_train,y_train)
y_pred=best_logreg.predict(X_test)
# Calculate accuracy
accuracy = accuracy_score(y_pred, y_test) 
print('{:s} : {:.3f}'.format("LogisticRegressor Accuracy", accuracy))
# Out:
# LogisticRegressor Accuracy : 0.762

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.05      0.09        84
#            1       0.76      1.00      0.86       256
#
#    micro avg       0.76      0.76      0.76       340
#    macro avg       0.78      0.52      0.48       340
# weighted avg       0.77      0.76      0.67       340

# %% [markdown]
# #
# Model fitting and evaluation--SVC

# %%
from sklearn.svm import SVC
# Create the hyperparameter grid
c_space = np.linspace(1,20,num = 20)
gamma_space=np.linspace(0,5,num=20)
_kernel=['linear','rbf','sigmoid']
param_grid = {'C': c_space,'gamma':gamma_space,'kernel':_kernel}
svc=SVC()
svc_cv = GridSearchCV(svc,param_grid,cv=10)

# Fit it to the training data
svc_cv.fit(X_train,y_train)

# Print the optimal parameters and best score
print("Tuned SVC Parameter: {}".format(svc_cv.best_params_))
print("Tuned SVC Accuracy: {}".format(svc_cv.best_score_))
# Out:
# Tuned SVC Parameter: {'C': 14.0, 'gamma': 5.0, 'kernel': 'rbf'}
# Tuned SVC Accuracy: 0.7786764705882353

# %%
best_svc=SVC(kernel='rbf',gamma=5,C=14)
best_svc.fit(X_train,y_train)
y_pred=best_svc.predict(X_test)
# Calculate accuracy
accuracy = accuracy_score(y_pred, y_test) 
print('{:s} : {:.3f}'.format("SVC Accuracy", accuracy))
# Out:
# SVC Accuracy : 0.779

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.15      0.26        84
#            1       0.78      0.98      0.87       256
#
#    micro avg       0.78      0.78      0.78       340
#    macro avg       0.77      0.57      0.56       340
# weighted avg       0.78      0.78      0.72       340

# %% [markdown]
# #
# Model fitting and evaluation--DT

# %%
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

max_d=np.linspace(1,20,num = 20)
param_dist = {"max_depth": max_d,
              "max_features": randint(1, 7),
              "min_samples_leaf": randint(1, 9),
              "criterion": ["gini", "entropy"]}

# Instantiate a Decision Tree classifier: tree
tree = DecisionTreeClassifier()

# Instantiate the RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(tree, param_dist, cv=10)

# Fit it to the data
tree_cv.fit(X_train,y_train)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'gini', 'max_depth': 2.0, 'max_features': 2, 'min_samples_leaf': 8}
# Best score is 0.775

# %%
best_dt = DecisionTreeClassifier(criterion='gini',max_depth=2,max_features=2,min_samples_leaf=8, random_state=42)
best_dt.fit(X_train,y_train)
y_pred=best_dt.predict(X_test)
accuracy = accuracy_score(y_pred, y_test) 
print('{:s} : {:.3f}'.format("DecisionTree Accuracy", accuracy))
# Out:
# DecisionTree Accuracy : 0.776

# %% [markdown]
# #
# voting classifier

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
# Set seed for reproducibility
SEED=42
# Instantiate lr
lr = LogisticRegression(C=13,solver='lbfgs',random_state=SEED)
# Instantiate knn
knn = KNN(n_neighbors=10)
# Instantiate dt
dt = DecisionTreeClassifier(criterion='gini',max_depth=2,max_features=2,min_samples_leaf=8, random_state=SEED)
# Instantiate SVC
svc=SVC(kernel="rbf",C=14,gamma=5)
# Define the list classifiers
classifiers = [('Logistic Regression', lr), ('K Nearest Neighbours', knn), ('Classification Tree', dt),('SVC',svc)]

# Iterate over the pre-defined list of classifiers
for clf_name, clf in classifiers:     
    # Fit clf to the training set
    clf.fit(X_train, y_train)       
    # Predict y_pred
    y_pred = clf.predict(X_test)   
    # Calculate accuracy
    accuracy = accuracy_score(y_pred, y_test) 
    # Evaluate clf's accuracy on the test set
    print('{:s} : {:.3f}'.format(clf_name, accuracy)) 
    # Evalutate MSE
    # print('MSE test: %.3f' % (mean_squared_error(y_test, y_pred)))

vc=VotingClassifier(estimators=classifiers)

vc.fit(X_train,y_train)
y_pred=vc.predict(X_test)

print('Voting Classifier:{}'.format(accuracy_score(y_test,y_pred)))
# Out:
# Logistic Regression : 0.762
# K Nearest Neighbours : 0.785
# Classification Tree : 0.776
# SVC : 0.779
# Voting Classifier:0.7764705882352941

# %% [markdown]
# #
# Adaboost

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier

# Instantiate dt with the best
best_dt = DecisionTreeClassifier(max_depth=2)

param_dist={'n_estimators':[120,140,160,180,200]}

# Instantiate ada
ada = AdaBoostClassifier(base_estimator=best_dt, random_state=SEED)
gs_cv = GridSearchCV(ada, param_dist, cv=10)

# Fit ada to the training set
gs_cv.fit(X_train, y_train)
print("Adaboost Decision Tree Parameters: {}".format(gs_cv.best_params_))
print("Best score is {}".format(gs_cv.best_score_))
# Out:
# Adaboost Decision Tree Parameters: {'n_estimators': 200}
# Best score is 0.7713235294117647

# %%
best_ada = AdaBoostClassifier(base_estimator=best_dt, n_estimators=200, random_state=SEED)
best_ada.fit(X_train,y_train)
y_pred=best_ada.predict(X_test)
accuracy = accuracy_score(y_pred, y_test) 
print('{:s} : {:.3f}'.format("Adaboost Accuracy", accuracy))
# Out:
# Adaboost Accuracy : 0.750

# %%
# Import roc_auc_score
from sklearn.metrics import roc_auc_score
ada = AdaBoostClassifier(base_estimator=best_dt, n_estimators=200, random_state=SEED)
ada.fit(X_train, y_train)
# Compute the probabilities of obtaining the positive class
y_pred_proba = ada.predict_proba(X_test)[:, 1]

# Evaluate test-set roc_auc_score
ada_roc_auc = roc_auc_score(y_test, y_pred_proba)

# Print roc_auc_score
print('ROC AUC score: {:.2f}'.format(ada_roc_auc))
# Out:
# ROC AUC score: 0.62

# %%
from sklearn.metrics import roc_curve
fpr,tpr,thresholds=roc_curve(y_test,y_pred_proba)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='L R')
plt.show()

# %% [markdown]
# # PART IV Multiple Classes
# Model fitting and evaluation--Multiclass

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(normalized_X,y_mul,test_size=0.2,random_state=42)
y_train.head()
# Out:
# 1376    Baa2
# 1323    Baa2
# 1179    Baa2
# 651       B2
# 464      Aa3
# Name: Rating, dtype: object

# %% [markdown]
# #
# Logistic Regression

# %%
# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
import math

# Create the hyperparameter grid
c_space = np.linspace(1,50,num = 50)
param_grid = {'C': c_space}

# Instantiate the logistic regression classifier: logreg
logreg = LogisticRegression(solver='lbfgs')

# Instantiate the GridSearchCV object: logreg_cv
logreg_cv = GridSearchCV(logreg,param_grid,cv=10)

# Fit it to the training data
logreg_cv.fit(X_train,y_train)

# Print the optimal parameters and best score
print("Tuned Logistic Regression Parameter: {}".format(logreg_cv.best_params_))
print("Tuned Logistic Regression Accuracy: {}".format(logreg_cv.best_score_))
# Out:
# G:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 2 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# G:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# G:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# G:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
best_logreg=LogisticRegression(C=45,penalty='l1')
best_logreg.fit(X_train,y_train)
y_pred=best_logreg.predict(X_test)
# Calculate accuracy
accuracy = accuracy_score(y_pred, y_test) 
print('{:s} : {:.3f}'.format("LogisticRegressor Accuracy", accuracy))
# Out:
# G:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# G:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegressor Accuracy : 0.185
# G:\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# #
# Ridge

# %%
from sklearn.linear_model import RidgeClassifierCV
ridge = RidgeClassifierCV(alphas=[0.001,0.01,0.1,1,10],normalize=True,cv=10)
ridge.fit(X_train,y_train)        
print("Tuned Ridge Classifier Accuracy: {}".format(ridge.score(X_train, y_train)))
print("Tuned Ridge Classifier Accuracy on Testset: {}".format(ridge.score(X_test, y_test)))
# Out:
# Tuned Ridge Classifier Accuracy: 0.19852941176470587
# Tuned Ridge Classifier Accuracy on Testset: 0.19117647058823528

# %% [markdown]
# #
# Decision Tree

# %%
from scipy.stats import randint
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV

max_d=np.linspace(1,100,num = 100)
min_s_s=np.linspace(0.1,1,num = 10)
param_dist = {"max_depth": max_d,
              'min_samples_split':min_s_s,
              "min_samples_leaf": randint(1, 20),
              "criterion": ["gini", "entropy"]}

# Instantiate a Decision Tree classifier: tree
tree = DecisionTreeClassifier()

# Instantiate the RandomizedSearchCV object: tree_cv
tree_cv = RandomizedSearchCV(tree, param_dist, cv=10)

# Fit it to the data
tree_cv.fit(X_train,y_train)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# G:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 2 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# Tuned Decision Tree Parameters: {'criterion': 'entropy', 'max_depth': 32.0, 'min_samples_leaf': 17, 'min_samples_split': 0.1}
# Best score is 0.25
# G:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
best_dt = DecisionTreeClassifier(criterion='gini',max_depth=97,min_samples_leaf=9, min_samples_split=0.1)
best_dt.fit(X_train,y_train)
y_pred=best_dt.predict(X_test)
accuracy = accuracy_score(y_pred, y_test) 
print('{:s} : {:.3f}'.format("DecisionTree Accuracy", accuracy))
# Out:
# DecisionTree Accuracy : 0.250

# %% [markdown]
# #
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
n_e=[500,550,600]
m_d=[44,46,48,50,52,54,56]
param_grid = { 'n_estimators': n_e,'max_depth': m_d,'criterion':['gini','entropy']}
rf=RandomForestClassifier()
gs = GridSearchCV(rf, param_grid, cv=10)
gs.fit(X_train, y_train)
print("Tuned Random Forest Parameter: {}".format(gs.best_params_))
print("Tuned Random Forest Accuracy: {}".format(gs.best_score_))
# Out:
# G:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 2 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)
# G:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Tuned Random Forest Parameter: {'criterion': 'gini', 'max_depth': 50, 'n_estimators': 550}
# Tuned Random Forest Accuracy: 0.6367647058823529

# %%
best_rf=RandomForestClassifier(n_estimators=550,max_depth=50,criterion='entropy')
best_rf.fit(X_train,y_train)
y_pred=best_rf.predict(X_test)
# Calculate accuracy
accuracy = accuracy_score(y_pred, y_test) 
print('{:s} : {:.3f}'.format("Random Forest Accuracy", accuracy))
# Out:
# Random Forest Accuracy : 0.671

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           A1       0.65      0.54      0.59        24
#           A2       0.65      0.45      0.54        33
#           A3       1.00      0.20      0.33         5
#          Aa2       0.89      0.53      0.67        15
#          Aa3       0.68      0.76      0.72        42
#           B1       1.00      0.32      0.48        19
#           B2       0.75      0.60      0.67         5
#           B3       0.67      0.29      0.40         7
#          Ba1       1.00      0.33      0.50         6
#          Ba2       0.50      0.65      0.57        23
#          Ba3       0.75      0.52      0.62        23
#         Baa1       0.82      0.58      0.68        31
#         Baa2       0.55      0.87      0.67        63
#         Baa3       0.60      0.79      0.68        43
#         Caa1       0.00      0.00      0.00         1
#
#    micro avg       0.64      0.64      0.64       340
# ...

# %%
best_rf=RandomForestClassifier(n_estimators=550,max_depth=50,criterion='gini')
best_rf.fit(X_train,y_train)
y_pred=best_rf.predict(X_test)
# Calculate accuracy
accuracy = accuracy_score(y_pred, y_test) 
print('{:s} : {:.3f}'.format("Random Forest Accuracy", accuracy))
# Out:
# Random Forest Accuracy : 0.650
